# %% [markdown]
# <a href="https://colab.research.google.com/github/manavsachdevaa/NLP-learning/blob/main/Trained_word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#USING PRETRAINED EMBEDDINGS
# 2. popular pretrained model
#1. google news Word2Vec (300)
#2. GloVe (Stanford)
# !pip install gensim
import gensim.downloader as api
print("Loading Pretrained models: ")
model=api.load("word2vec-google-news-300")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 68.0 MB/s eta 0:00:00
# ...
# Loading Pretrained models:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model.most_similar('deep')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2296678521.py in <cell line: 0>()
# ----> 1 model.most_similar('deep')
#
# NameError: name 'model' is not defined
